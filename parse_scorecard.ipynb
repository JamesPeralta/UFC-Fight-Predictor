# %% [markdown]
# # Get and parse scorecards

# %% [markdown]
# ### Import libraries

# %%
from pandas import read_csv, Series, DataFrame, concat
from datetime import datetime
from collections import Counter
from bs4 import BeautifulSoup
from requests import get
import re

# %% [markdown]
# ### Parse the csv and create panda models

# %%
def parse_location(location):
    words = location.strip().lower().split(', ')
    length = len(words)
    return Series((words[0], words[1])) if length == 2 else Series((words[0], words[-1]))


data = read_csv('ufcdata/data.csv')
data['date'] = data['date'].apply(lambda dt: datetime.strptime(dt, '%Y-%m-%d'))
data[['city', 'country']] = data.apply(lambda row: Series(parse_location(row['location'])), axis=1)

counter = Counter(data['R_fighter'].append(data['B_fighter']))
fighter_counts = DataFrame(zip(counter.keys(), counter.values()), columns=['fighter', 'count'])
fighter_counts.sort_values(by='count', inplace=True, ascending=False)

locations = data.groupby(['date', 'city', 'country']).size().reset_index(name='no_fights_in_card')
locations.sort_values(by='date', inplace=True)

display(data.head(), fighter_counts.head(), locations.head())
# Out:
#               R_fighter       B_fighter          Referee       date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard 2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal 2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta 2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald 2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta 2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 0                    0.0  ...                           0.0     8.0  Orthodox
# 1                    0.0  ...                           0.0     5.0  Southpaw
# 2                    0.0  ...                           1.0    14.0  Orthodox
# 3                    0.0  ...                           0.0     6.0  Orthodox
# 4                    0.0  ...                           0.0     3.0  Southpaw
#
#    R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age     city  country
# 0        162.56       162.56         135.0   31.0   32.0  chicago      usa
# 1        165.10       167.64         125.0   32.0   31.0  chicago      usa
# 2        180.34       193.04         155.0   36.0   35.0  chicago      usa
# 3        162.56       172.72         135.0   26.0   29.0  chicago      usa
# 4        187.96       190.50         264.0   32.0   26.0  chicago      usa
#
# [5 rows x 147 columns]
#              fighter  count
# 272   Donald Cerrone     32
# 72        Jim Miller     32
# 152  Jeremy Stephens     30
# 476  Michael Bisping     29
# 155    Diego Sanchez     29
#         date       city country  no_fights_in_card
# 0 1993-11-12     denver     usa                  8
# 1 1994-03-11     denver     usa                 15
# 2 1994-09-09  charlotte     usa                  6
# 3 1994-12-16      tulsa     usa                  8
# 4 1995-04-07  charlotte     usa                  9

# %% [markdown]
# ### Save the html for list of UFC events

# %%
list_ufc_url = 'https://en.wikipedia.org/wiki/List_of_UFC_events'
past_events_list_parser = BeautifulSoup(get(list_ufc_url).text, 'html.parser')

# %%
def past_event_parse(event):
    tds = event.findAll('td')
    locs = tds[4].text.strip().lower().split(', ')
    attendance = re.sub('\D', '', tds[5].text.strip())
    
    country = locs[-1].replace('.', '')
    city = locs[0].replace('.', '')
    
    return {
        'event_name': tds[1].text.strip(),
        'url': 'https://en.wikipedia.org' + tds[1].find('a')['href'] if tds[1].find('a') is not None else '',
        'date': datetime.strptime(tds[2].text.strip(), '%b %d, %Y'),
        'venue': tds[3].text.strip(),
        'city': locs[0].replace('.', '').strip(),
        'country': country.strip() if country != 'us' else 'usa',
        'attendance': int(attendance) if len(attendance) > 0 else None,
    }

past_events = DataFrame(map(past_event_parse, past_events_list_parser.find('table', {'id': 'Past_events'}).findAll('tr')[1:][::-1]))
past_events.drop(past_events.loc[past_events['url'] == ''].index, inplace=True)
past_events.reset_index(inplace=True, drop=True)

display(past_events.tail(), past_events.shape)
# Out:
#                                  event_name  \
# 500          UFC on ESPN: Reyes vs. Weidman
# 501        UFC Fight Night: Maia vs. Askren
# 502              UFC 244: Masvidal vs. Diaz
# 503       UFC Fight Night: Zabit vs. Kattar
# 504  UFC Fight Night: Błachowicz vs. Jacaré
#
#                                                    url       date  \
# 500  https://en.wikipedia.org/wiki/UFC_on_ESPN:_Rey... 2019-10-18
# 501  https://en.wikipedia.org/wiki/UFC_Fight_Night:... 2019-10-26
# 502              https://en.wikipedia.org/wiki/UFC_244 2019-11-02
# 503  https://en.wikipedia.org/wiki/UFC_Fight_Night:... 2019-11-09
# 504  https://en.wikipedia.org/wiki/UFC_Fight_Night:... 2019-11-16
#
#                         venue           city    country  attendance
# 500                 TD Garden         boston        usa     12066.0
# 501  Singapore Indoor Stadium        kallang  singapore      7155.0
# 502     Madison Square Garden  new york city        usa     20143.0
# 503                CSKA Arena         moscow     russia     11305.0
# 504     Ginásio do Ibirapuera      são paulo     brazil     10344.0
# (505, 7)

# %% [markdown]
# ### Save the htmls for each UFC night

# %%
past_events['html'] = past_events['url'].apply(lambda url: BeautifulSoup(get(url).text, 'html.parser') if len(url) > 0 else '')

# %% [markdown]
# ### Parse and split each UFC night into different fights

# %%
def parse_event(event):
    if len(event) == 0:
        return []
    
    fights = []
    rows = event.find('table', {'class': 'toccolours'}).findAll('tr')

    for fight in rows:
        if fight.find('th') is None:
            cols = fight.findAll('td')
            
            winner = cols[1].text.strip()
            loser = cols[3].text.strip()
            
            win_condition = cols[4].text.strip().lower()
            method = ''
            how = ''
            if 'decision' in win_condition:
                method = 'decision'
                
                splits = win_condition.split(' (')
                if win_condition == 'decision':
                    how = ''
                elif len(splits) < 3:
                    how = re.sub('[^a-z ]+', '', re.sub('decision', '', win_condition).strip()).strip()
                else:
                    how = re.sub('[()]+', '', win_condition.split(' (')[2]).strip()
            else:
                method = win_condition.split(' (')[0] .strip()
                how = ' '.join(re.sub('[^a-z ]+', '', win_condition).split()[1:])
                
            n_round = cols[5].text.strip()
            n_round = int(n_round) if len(n_round) > 0 else None
            
            method = 'disqualification' if method == 'dq' else method
            method = method if 'submission' not in method else 'submission'
            method = method if 'referee stoppage' not in method else 'tko'
            
            how = how.replace('dq', '')
            how = how.replace('submission', '')
            how = how.replace('disqualification', '')

            fights.append([winner.strip(), loser.strip(), method.strip(), how.strip(), n_round])
    return fights


past_events['full_fight_info'] = past_events['html'].apply(lambda html: parse_event(html))
past_events = past_events.explode('full_fight_info')
past_events.reset_index(inplace=True)

fights = past_events['full_fight_info'].apply(Series)
fights.rename(columns={0: 'winner', 1: 'loser', 2: 'method', 3: 'how', 4: 'round'}, inplace=True)

all_fights = concat([past_events, fights], axis=1)
all_fights.drop(columns=['index', 'html', 'full_fight_info'], inplace=True)
all_fights = all_fights[['winner', 'loser', 'method', 'how', 'round', 'event_name', 'date', 'venue', 'city', 'country', 'attendance', 'url']]

# %% [markdown]
# ### Cleaning up some rows

# %%
invalid_rows = all_fights.loc[all_fights['winner'].isnull() | all_fights['loser'].isnull() | all_fights['date'].isnull() | all_fights['url'] == ''].index
all_fights.drop(invalid_rows, inplace=True)

invalid_rows = all_fights.loc[(all_fights['winner'] == '') | (all_fights['loser'] == '')].index
all_fights.drop(invalid_rows, inplace=True)

all_fights['winner'] = all_fights['winner'].apply(lambda name: re.sub('\(.*?\)', '', name))
all_fights['loser'] = all_fights['loser'].apply(lambda name: re.sub('\(.*?\)', '', name))
all_fights.reset_index(inplace=True, drop=True)

display(all_fights.tail(), all_fights.shape)
# Out:
# /home/satyaki/env/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#                         winner              loser      method  \
# 5486        Francisco Trinaldo        Bobby Green    decision
# 5487               Randy Brown      Warlley Alves  submission
# 5488  Douglas Silva de Andrade        Renan Barão    decision
# 5489             Ariane Lipski  Isabella de Pádua    decision
# 5490              Tracy Cortez       Vanessa Melo    decision
#
#                       how  round                              event_name  \
# 5486  30–27, 29–28, 29–28    3.0  UFC Fight Night: Błachowicz vs. Jacaré
# 5487       triangle choke    2.0  UFC Fight Night: Błachowicz vs. Jacaré
# 5488  30–27, 30–27, 30–26    3.0  UFC Fight Night: Błachowicz vs. Jacaré
# 5489  30–26, 30–26, 29–27    3.0  UFC Fight Night: Błachowicz vs. Jacaré
# 5490  30–27, 30–27, 29–28    3.0  UFC Fight Night: Błachowicz vs. Jacaré
#
#            date                  venue       city country  attendance  \
# 5486 2019-11-16  Ginásio do Ibirapuera  são paulo  brazil     10344.0
# 5487 2019-11-16  Ginásio do Ibirapuera  são paulo  brazil     10344.0
# 5488 2019-11-16  Ginásio do Ibirapuera  são paulo  brazil     10344.0
# 5489 2019-11-16  Ginásio do Ibirapuera  são paulo  brazil     10344.0
# 5490 2019-11-16  Ginásio do Ibirapuera  são paulo  brazil     10344.0
#
#                                                     url
# 5486  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 5487  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 5488  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 5489  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 5490  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# (5491, 12)

# %% [markdown]
# ### Save the scorecard data as csv

# %%
# Columns
# winner (string): who won
# loser (string): who lost
# method (category): how they won - knockout, submissions, decision, etc.
# how (string/category): more specifics on how they won - head kick, punch, etc.
# round (int): which round they won
# event_name (string): UFC event name
# date (date)
# venue (string)
# city (string)
# country (string)
# attendance (int): number of people at the event
# url (string): url for the event

all_fights.to_csv('ufcdata/scorecard.csv', index=False)

# %%
for col in ['winner', 'loser', 'method', 'how', 'round', 'city', 'country']:
    display(all_fights.groupby(col).size().reset_index(name='count').sort_values(by=['count'], ascending=False))
# Out:
#                  winner                loser method how  round  \
# 2060         Jon Jones         Dan Henderson               NaN
# 2061   Jake Ellenberger           Jay Hieron               NaN
# 2062       Dennis Siver          Eddie Yagin               NaN
# 2063     Dennis Hallman       Thiago Tavares               NaN
# 2064       John Lineker  Yasuhiro Urushitani               NaN
# 2065    Michael Johnson       Danny Castillo               NaN
# 2066    Takeya Mizugaki        Jeff Hougland               NaN
# 2067          Tim Means        Abel Trujillo               NaN
# 2068  Daron Cruickshank       Henry Martinez               NaN
# 2069       Shane Roller       Jacob Volkmann               NaN
# 2070          Kyle Noke    Charlie Brenneman               NaN
# 2879         José Aldo           Chad Mendes               NaN
# 2880      Ronaldo Souza       Gegard Mousasi               NaN
# 2881       Gray Maynard      Fabrício Camões               NaN
# 2882      Bethe Correia       Shayna Baszler               NaN
# 2883    Jussier Formiga        Zach Makovsky               NaN
# 2884         James Vick        Valmir Lazaro               NaN
# 2885      Lorenz Larkin        Derek Brunson               NaN
# 2886        Bobby Green        Abel Trujillo               NaN
# 2887      Tony Ferguson       Danny Castillo               NaN
# 2888     Beneil Dariush          Tony Martin               NaN
# 2889        Alex Garcia           Matt Dwyer               NaN
# 3941      Ricardo Lamas            B.J. Penn               NaN
# 3942      Derrick Lewis        Marcin Tybura               NaN
# 3943        Jenel Lausa           Yao Zhikui               NaN
# 3944        Cole Miller        Mizuto Hirota               NaN
# 3945          Sam Alvey       Alex Nicholson               NaN
# 3946           Jon Tuck     Alex Volkanovski               NaN
# 3947       Dong Yi Yang           Ryan Janes               NaN
# 3948        Seo Hee Ham      Danielle Taylor               NaN
# 3949    James Moontasri          Alex Morono               NaN
# 3950    Kyoji Horiguchi       Ali Bagautinov               NaN
# 3951     Damir Hadzovic        Yusuke Kasuya               NaN
# 5017      Robbie Lawler           Ben Askren               NaN
# 5018   Joseph Benavidez  Deiveson Figueiredo               NaN
# 5019      Cortney Casey     Cynthia Calvillo               NaN
# 5020         James Vick          Paul Felder               NaN
# 5021    Aleksandra Albu       Emily Whitmire               NaN
# 5022       Markus Perez    Anthony Hernandez               NaN
# 5023      Marion Reneau      Yana Kunitskaya               NaN
# 5024        Kron Gracie         Alex Caceres               NaN
# 5025     Manny Bermudez         Benito Lopez               NaN
#
#                            event_name       date                       venue  \
# 2060     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2061     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2062     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2063     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2064     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2065     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2066     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2067     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2068     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2069     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2070     UFC 151: Jones vs. Henderson 2012-09-01  Mandalay Bay Events Center
# 2879      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2880      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2881      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2882      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2883      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2884      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2885      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2886      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2887      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2888      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 2889      UFC 176: Aldo vs. Mendes II 2014-08-02              Staples Center
# 3941  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3942  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3943  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3944  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3945  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3946  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3947  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3948  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3949  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3950  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 3951  UFC Fight Night: Lamas vs. Penn 2016-10-15          Mall of Asia Arena
# 5017                          UFC 233 2019-01-26                Honda Center
# 5018                          UFC 233 2019-01-26                Honda Center
# 5019                          UFC 233 2019-01-26                Honda Center
# 5020                          UFC 233 2019-01-26                Honda Center
# 5021                          UFC 233 2019-01-26                Honda Center
# 5022                          UFC 233 2019-01-26                Honda Center
# 5023                          UFC 233 2019-01-26                Honda Center
# 5024                          UFC 233 2019-01-26                Honda Center
# 5025                          UFC 233 2019-01-26                Honda Center
#
#              city      country  attendance  \
# 2060    las vegas          usa         NaN
# 2061    las vegas          usa         NaN
# 2062    las vegas          usa         NaN
# 2063    las vegas          usa         NaN
# 2064    las vegas          usa         NaN
# 2065    las vegas          usa         NaN
# 2066    las vegas          usa         NaN
# 2067    las vegas          usa         NaN
# 2068    las vegas          usa         NaN
# 2069    las vegas          usa         NaN
# 2070    las vegas          usa         NaN
# 2879  los angeles          usa         NaN
# 2880  los angeles          usa         NaN
# 2881  los angeles          usa         NaN
# 2882  los angeles          usa         NaN
# 2883  los angeles          usa         NaN
# 2884  los angeles          usa         NaN
# 2885  los angeles          usa         NaN
# 2886  los angeles          usa         NaN
# 2887  los angeles          usa         NaN
# 2888  los angeles          usa         NaN
# 2889  los angeles          usa         NaN
# 3941        pasay  philippines         NaN
# 3942        pasay  philippines         NaN
# 3943        pasay  philippines         NaN
# 3944        pasay  philippines         NaN
# 3945        pasay  philippines         NaN
# 3946        pasay  philippines         NaN
# 3947        pasay  philippines         NaN
# 3948        pasay  philippines         NaN
# 3949        pasay  philippines         NaN
# 3950        pasay  philippines         NaN
# 3951        pasay  philippines         NaN
# 5017      anaheim          usa         NaN
# 5018      anaheim          usa         NaN
# 5019      anaheim          usa         NaN
# 5020      anaheim          usa         NaN
# 5021      anaheim          usa         NaN
# 5022      anaheim          usa         NaN
# 5023      anaheim          usa         NaN
# 5024      anaheim          usa         NaN
# 5025      anaheim          usa         NaN
#
#                                                     url
# 2060              https://en.wikipedia.org/wiki/UFC_151
# 2061              https://en.wikipedia.org/wiki/UFC_151
# 2062              https://en.wikipedia.org/wiki/UFC_151
# 2063              https://en.wikipedia.org/wiki/UFC_151
# 2064              https://en.wikipedia.org/wiki/UFC_151
# 2065              https://en.wikipedia.org/wiki/UFC_151
# 2066              https://en.wikipedia.org/wiki/UFC_151
# 2067              https://en.wikipedia.org/wiki/UFC_151
# 2068              https://en.wikipedia.org/wiki/UFC_151
# 2069              https://en.wikipedia.org/wiki/UFC_151
# 2070              https://en.wikipedia.org/wiki/UFC_151
# 2879              https://en.wikipedia.org/wiki/UFC_176
# 2880              https://en.wikipedia.org/wiki/UFC_176
# 2881              https://en.wikipedia.org/wiki/UFC_176
# 2882              https://en.wikipedia.org/wiki/UFC_176
# 2883              https://en.wikipedia.org/wiki/UFC_176
# 2884              https://en.wikipedia.org/wiki/UFC_176
# 2885              https://en.wikipedia.org/wiki/UFC_176
# 2886              https://en.wikipedia.org/wiki/UFC_176
# 2887              https://en.wikipedia.org/wiki/UFC_176
# 2888              https://en.wikipedia.org/wiki/UFC_176
# 2889              https://en.wikipedia.org/wiki/UFC_176
# 3941  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3942  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3943  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3944  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3945  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3946  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3947  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3948  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3949  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3950  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 3951  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 5017              https://en.wikipedia.org/wiki/UFC_233
# 5018              https://en.wikipedia.org/wiki/UFC_233
# 5019              https://en.wikipedia.org/wiki/UFC_233
# 5020              https://en.wikipedia.org/wiki/UFC_233
# 5021              https://en.wikipedia.org/wiki/UFC_233
# 5022              https://en.wikipedia.org/wiki/UFC_233
# 5023              https://en.wikipedia.org/wiki/UFC_233
# 5024              https://en.wikipedia.org/wiki/UFC_233
# 5025              https://en.wikipedia.org/wiki/UFC_233
# url
# https://en.wikipedia.org/wiki/UFC_151                            11
# https://en.wikipedia.org/wiki/UFC_176                            11
# https://en.wikipedia.org/wiki/UFC_233                             9
# https://en.wikipedia.org/wiki/UFC_Fight_Night:_Lamas_vs._Penn    11
# dtype: int64
#                  winner  count
# 655          Jon Jones      25
# 362      Donald Cerrone     22
# 336         Demian Maia     22
# 605          Jim Miller     20
# 462  Georges St-Pierre      19
# ..                  ...    ...
# 399     Emil Weber Meek      1
# 398       Elvis Sinosic      1
# 967      Milana Dudieva      1
# 968         Miles Johns      1
# 709       Justin Martin      1
#
# [1419 rows x 2 columns]
#                 loser  count
# 849   Jeremy Stephens     16
# 1897    Vitor Belfort     15
# 1388        Nate Diaz     14
# 1404        Nick Diaz     14
# 287      Chael Sonnen     14
# ...               ...    ...
# 1269   Masutatsu Yano      1
# 1270  Matheus Nicolau      1
# 1272    Matt Andersen      1
# 1277     Matt Frevola      1
# 0         Aaron Brink      1
#
# [1969 rows x 2 columns]
#              method  count
# 1          decision   2405
# 6        submission   1171
# 7               tko   1158
# 4                ko    612
# 5        no contest     51
# 0                       42
# 3              draw     37
# 2  disqualification     15
#                         how  count
# 393                 punches    979
# 169     30–27, 30–27, 30–27    436
# 404         rearnaked choke    397
# 87      29–28, 29–28, 29–28    375
# 313        guillotine choke    181
# ..                      ...    ...
# 190     48–46, 48–47, 48–46      1
# 189     48–46, 48–46, 49–46      1
# 187     48–46, 48–45, 48–46      1
# 186     48–45, 48–46, 49–46      1
# 458  wheel kick and punches      1
#
# [459 rows x 2 columns]
#    round  count
# 2    3.0   2644
# 0    1.0   1466
# 1    2.0    875
# 4    5.0    223
# 3    4.0     39
#                city  count
# 75        las vegas   1223
# 120  rio de janeiro    119
# 78           london    114
# 143       são paulo    102
# 4           anaheim     93
# ..              ...    ...
# 140       summerlin      9
# 23     bossier city      8
# 88            miami      8
# 156        yokohama      7
# 35            chiba      7
#
# [158 rows x 2 columns]
#                  country  count
# 25                   usa   3580
# 2                 brazil    429
# 3                 canada    367
# 22                    uk    255
# 1              australia    173
# 11                 japan     82
# 21                sweden     72
# 12                mexico     72
# 9                germany     67
# 5                  china     62
# 19             singapore     46
# 18                russia     36
# 23  united arab emirates     31
# 10               ireland     30
# 13           netherlands     25
# 15           philippines     23
# 16                poland     23
# 14           new zealand     21
# 8                denmark     13
# 7         czech republic     13
# 6                croatia     13
# 4                  chile     13
# 24               uruguay     13
# 0              argentina     12
# 20           south korea     11
# 17           puerto rico      9
