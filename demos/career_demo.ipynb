# %% [markdown]
# # In this Notebook we are attempting to predict a persons next N fights

# %% [markdown]
# ## Library Imports

# %%
import sys
sys.path.insert(1, '../combined_data')

import pandas as pd
import numpy as np
import talos as ta

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

from talos.model.normalizers import lr_normalizer
from talos.model.hidden_layers import hidden_layers

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Conv1D, Flatten, MaxPooling1D, LSTM, Input
from keras.optimizers import Adam, Nadam, RMSprop
from keras.losses import logcosh, binary_crossentropy
from keras.activations import relu, elu, sigmoid

import matplotlib.pyplot as plt
# %matplotlib inline

from make_career import make_career
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the dataset

# %%
features, labels = make_career(N_FIGHT_CAREER=10, N_FUTURE_LABELS=5)
# Out:
# Creating careers using 10 fight intervals and predicting 5 future fights
# Original fight data shape: (5062, 153)
# Fights 2x shape: (10124, 95)
#
# Features shape: (600, 10)
# Labels shape: (600, 5)
#
# Features is a 2D matrix with 600 rows
# Each row contains has 10 fights, and each fight has 100 keys
#
# Labels is a 2D matrix with 600 rows
# Each row contains the the prediction for the next 5 fight(s)

# %%
print('Features {}'.format(features.shape))
print('Labels {}'.format(labels.shape))
# Out:
# Features (600, 10)
# Labels (600, 5)

# %%
# Get the first fight window and the first fight in that window
def get_column_types():
    num_cols = []
    cat_cols = []
    for fight in features[0][0]:
        feature_type = type(features[1][1][fight])
        if feature_type is not float and feature_type is not int:
            cat_cols.append(fight)
        else:
            num_cols.append(fight)
            
    return num_cols, cat_cols


def plot_training():
    acc_1 = history.history['Fight_1_accuracy']
    acc_2 = history.history['Fight_2_accuracy']
    acc_3 = history.history['Fight_3_accuracy']
    acc_4 = history.history['Fight_4_accuracy']
    acc_5 = history.history['Fight_5_accuracy']
    
    val_acc_1 = history.history['val_Fight_1_accuracy']
    val_acc_2 = history.history['val_Fight_2_accuracy']
    val_acc_3 = history.history['val_Fight_3_accuracy']
    val_acc_4 = history.history['val_Fight_4_accuracy']
    val_acc_5 = history.history['val_Fight_5_accuracy']
    
    epochs = range(1, len(acc_1) + 1)

    fig, (accuracy_axis, training_axis) = plt.subplots(1, 2, figsize=(20, 5))

    accuracy_axis.plot(epochs, acc_1, 'b', label='Fight 1 Acc')
    accuracy_axis.plot(epochs, acc_2, 'g', label='Fight 2 Acc')
    accuracy_axis.plot(epochs, acc_3, 'r', label='Fight 3 Acc')
    accuracy_axis.plot(epochs, acc_4, 'c', label='Fight 4 Acc')
    accuracy_axis.plot(epochs, acc_5, 'm', label='Fight 5 Acc')
    accuracy_axis.set_title('Training Set Accuracy over time')
    accuracy_axis.set_ylabel('Accuracy')
    accuracy_axis.set_xlabel('Epoch')
    accuracy_axis.legend()
    
    training_axis.plot(epochs, val_acc_1, 'b', label='Fight 1 Acc')
    training_axis.plot(epochs, val_acc_2, 'g', label='Fight 2 Acc')
    training_axis.plot(epochs, val_acc_3, 'r', label='Fight 3 Acc')
    training_axis.plot(epochs, val_acc_4, 'c', label='Fight 4 Acc')
    training_axis.plot(epochs, val_acc_5, 'm', label='Fight 5 Acc')
    training_axis.set_title('Test Set Accuracy over time')
    training_axis.set_ylabel('Accuracy')
    training_axis.set_xlabel('Epoch')
    training_axis.legend()
    fig.show()

    
def encode_all_labels():
    encoded_labels = []
    for row in labels:
        new_labels_list = []
        for elem in row:
            if elem:
                new_labels_list.append(1)
            else:
                new_labels_list.append(0)
        encoded_labels.append(new_labels_list)
    encoded_labels = np.array(encoded_labels)
    
    return encoded_labels


def convert_labels(y_train):  
    fights_1 = np.array(y_train[:,0])
    fights_2 = np.array(y_train[:,1])
    fights_3 = np.array(y_train[:,2])
    fights_4 = np.array(y_train[:,3])
    fights_5 = np.array(y_train[:,4])
    
    y_train = [fights_1, fights_2, fights_3, fights_4, fights_5]
    return y_train

# %% [markdown]
# ## Preprocess Features

# %% [markdown]
# ## Generates np.array of shape (3220, 5 * features)

# %%
def collapse_n_fights():
    num_cols, cat_cols = get_column_types()
    
    # Collect only the features we want
    new_features = []
    for window in features:
        window_arr = list(window.reshape(1,-1))[0]
        fight_window = np.array([])
        for fight in window_arr:
            fight_arr = np.array([fight[i] for i in num_cols])
            np.nan_to_num(fight_arr, copy=False)
            fight_window = np.append(fight_window, fight_arr)
        new_features.append(fight_window)
    
    new_features, new_labels = shuffle(np.array(new_features), labels)
    X_train, X_test, y_train, y_test = train_test_split(new_features, new_labels, random_state=0, train_size=0.99)
    
    # Scale the data
    scaler = StandardScaler().fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    print('X_train length {}, y_train length {}'.format(X_train.shape, y_train.shape))
    print('X_test length {}, y_test length {}'.format(X_test.shape, y_test.shape))

    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Building a CNN to predict the winner using last n fights

# %%
# Get the data
labels = encode_all_labels()
X_train, X_test, y_train, y_test = collapse_n_fights()
X_train = X_train.reshape(X_train.shape[0], 10, 97)
X_test = X_test.reshape(X_test.shape[0], 10, 97)

y_train = np.array(convert_labels(y_train))
y_test = np.array(convert_labels(y_test))
# Out:
# X_train length (594, 970), y_train length (594, 5)
# X_test length (6, 970), y_test length (6, 5)

# %%
def get_ensemble():
    # x_train, y_train, x_val, y_val, params, test_model=False
    fight_input = Input(shape=(10, 97), name="Input")
    x = Conv1D(filters=128, kernel_size=2, activation='relu', name="Conv_1D")(fight_input)
    x = Dropout(0.01, name="Dropout")(x)
    x = Flatten(name="Flatten")(x)

    # Global Dense Network
    x = Dense(128, activation='relu', name="Global_Dense")(x)

    # 5 output layers
    fight_1 = Dense(1, activation='sigmoid', name="Fight_1")(x)
    fight_2 = Dense(1, activation='sigmoid', name="Fight_2")(x)
    fight_3 = Dense(1, activation='sigmoid', name="Fight_3")(x)
    fight_4 = Dense(1, activation='sigmoid', name="Fight_4")(x)
    fight_5 = Dense(1, activation='sigmoid', name="Fight_5")(x)

    model = Model(inputs=fight_input,
                  outputs=[fight_1, fight_2, fight_3, fight_4, fight_5])
    
    model.compile(optimizer='rmsprop',
                 loss={"Fight_1": "binary_crossentropy", 
                       "Fight_2": "binary_crossentropy",
                       "Fight_3": "binary_crossentropy",
                       "Fight_4": "binary_crossentropy",
                       "Fight_5": "binary_crossentropy"},
                 loss_weights={"Fight_1": 1., 
                               "Fight_2": 1.,
                               "Fight_3": 1.,
                               "Fight_4": 1.,
                               "Fight_5": 1.},
                 metrics={"Fight_1": "accuracy", 
                          "Fight_2": "accuracy",
                          "Fight_3": "accuracy",
                          "Fight_4": "accuracy",
                          "Fight_5": "accuracy"})

    model.summary()
    return model

model = get_ensemble()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 10, 97)       0
# __________________________________________________________________________________________________
# Conv_1D (Conv1D)                (None, 9, 128)       24960       Input[0][0]
# __________________________________________________________________________________________________
# Dropout (Dropout)               (None, 9, 128)       0           Conv_1D[0][0]
# __________________________________________________________________________________________________
# Flatten (Flatten)               (None, 1152)         0           Dropout[0][0]
# __________________________________________________________________________________________________
# Global_Dense (Dense)            (None, 128)          147584      Flatten[0][0]
# __________________________________________________________________________________________________
# Fight_1 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_2 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_3 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_4 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_5 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# ==================================================================================================
# Total params: 173,189
# Trainable params: 173,189
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train,
                    {'Fight_1': y_train[0], 
                     'Fight_2': y_train[1], 
                     'Fight_3': y_train[2], 
                     'Fight_4': y_train[3],
                     'Fight_5': y_train[4],},
                   validation_split=0.2,
                   batch_size=32,
                   epochs=10,
                   verbose=1)
# Out:
# Train on 475 samples, validate on 119 samples
# Epoch 1/10
# 475/475 [==============================] - 1s 2ms/step - loss: 3.8286 - Fight_1_loss: 0.7730 - Fight_2_loss: 0.8101 - Fight_3_loss: 0.7436 - Fight_4_loss: 0.7432 - Fight_5_loss: 0.7568 - Fight_1_accuracy: 0.5284 - Fight_2_accuracy: 0.5179 - Fight_3_accuracy: 0.5095 - Fight_4_accuracy: 0.5137 - Fight_5_accuracy: 0.4989 - val_loss: 3.4329 - val_Fight_1_loss: 0.6951 - val_Fight_2_loss: 0.6782 - val_Fight_3_loss: 0.6876 - val_Fight_4_loss: 0.6906 - val_Fight_5_loss: 0.6899 - val_Fight_1_accuracy: 0.5546 - val_Fight_2_accuracy: 0.6218 - val_Fight_3_accuracy: 0.5546 - val_Fight_4_accuracy: 0.5378 - val_Fight_5_accuracy: 0.5798
# Epoch 2/10
# 475/475 [==============================] - 0s 386us/step - loss: 3.1499 - Fight_1_loss: 0.6308 - Fight_2_loss: 0.6289 - Fight_3_loss: 0.6113 - Fight_4_loss: 0.6340 - Fight_5_loss: 0.6452 - Fight_1_accuracy: 0.6316 - Fight_2_accuracy: 0.6526 - Fight_3_accuracy: 0.6800 - Fight_4_accuracy: 0.6526 - Fight_5_accuracy: 0.6274 - val_loss: 3.6571 - val_Fight_1_loss: 0.7265 - val_Fight_2_loss: 0.7202 - val_Fight_3_loss: 0.7247 - val_Fight_4_loss: 0.7379 - val_Fight_5_loss: 0.7501 - val_Fight_1_accuracy: 0.4874 - val_Fight_2_accuracy: 0.4706 - val_Fight_3_accuracy: 0.5042 - val_Fight_4_accuracy: 0.5294 - val_Fight_5_accuracy: 0.4874
# Epoch 3/10
# 475/475 [==============================] - 0s 638us/step - loss: 2.8303 - Fight_1_loss: 0.5698 - Fight_2_loss: 0.5691 - Fight_3_loss: 0.5509 - Fight_4_loss: 0.5429 - Fight_5_loss: 0.5952 - Fight_1_accuracy: 0.7368 - Fight_2_accuracy: 0.7137 - Fight_3_accuracy: 0.7347 - Fight_4_accuracy: 0.7411 - Fight_5_accuracy: 0.7011 - val_loss: 3.6587 - val_Fight_1_loss: 0.7237 - val_Fight_2_loss: 0.6858 - val_Fight_3_loss: 0.7533 - val_Fight_4_loss: 0.7795 - val_Fight_5_loss: 0.7271 - val_Fight_1_accuracy: 0.5546 - val_Fight_2_accuracy: 0.5882 - val_Fight_3_accuracy: 0.5294 - val_Fight_4_accuracy: 0.4790 - val_Fight_5_accuracy: 0.5546
# Epoch 4/10
# 475/475 [==============================] - 0s 469us/step - loss: 2.5583 - Fight_1_loss: 0.5181 - Fight_2_loss: 0.5261 - Fight_3_loss: 0.4837 - Fight_4_loss: 0.4906 - Fight_5_loss: 0.5406 - Fight_1_accuracy: 0.7579 - Fight_2_accuracy: 0.7621 - Fight_3_accuracy: 0.7874 - Fight_4_accuracy: 0.7579 - Fight_5_accuracy: 0.7200 - val_loss: 3.7856 - val_Fight_1_loss: 0.7931 - val_Fight_2_loss: 0.7426 - val_Fight_3_loss: 0.7388 - val_Fight_4_loss: 0.8238 - val_Fight_5_loss: 0.6996 - val_Fight_1_accuracy: 0.5210 - val_Fight_2_accuracy: 0.5378 - val_Fight_3_accuracy: 0.5630 - val_Fight_4_accuracy: 0.4958 - val_Fight_5_accuracy: 0.5378
# Epoch 5/10
# 475/475 [==============================] - 0s 377us/step - loss: 2.2415 - Fight_1_loss: 0.4501 - Fight_2_loss: 0.4609 - Fight_3_loss: 0.4247 - Fight_4_loss: 0.4458 - Fight_5_loss: 0.4637 - Fight_1_accuracy: 0.7937 - Fight_2_accuracy: 0.7916 - Fight_3_accuracy: 0.8232 - Fight_4_accuracy: 0.8042 - Fight_5_accuracy: 0.8105 - val_loss: 4.0942 - val_Fight_1_loss: 0.7673 - val_Fight_2_loss: 0.7176 - val_Fight_3_loss: 0.8010 - val_Fight_4_loss: 1.0774 - val_Fight_5_loss: 0.7476 - val_Fight_1_accuracy: 0.5210 - val_Fight_2_accuracy: 0.5546 - val_Fight_3_accuracy: 0.5378 - val_Fight_4_accuracy: 0.4622 - val_Fight_5_accuracy: 0.5294
# Epoch 6/10
# 475/475 [==============================] - 0s 318us/step - loss: 2.0403 - Fight_1_loss: 0.3994 - Fight_2_loss: 0.4100 - Fight_3_loss: 0.3686 - Fight_4_loss: 0.4400 - Fight_5_loss: 0.4281 - Fight_1_accuracy: 0.8421 - Fight_2_accuracy: 0.8442 - Fight_3_accuracy: 0.8589 - Fight_4_accuracy: 0.8084 - Fight_5_accuracy: 0.8147 - val_loss: 3.9766 - val_Fight_1_loss: 0.7969 - val_Fight_2_loss: 0.7587 - val_Fight_3_loss: 0.7648 - val_Fight_4_loss: 0.9158 - val_Fight_5_loss: 0.7604 - val_Fight_1_accuracy: 0.4874 - val_Fight_2_accuracy: 0.6050 - val_Fight_3_accuracy: 0.5378 - val_Fight_4_accuracy: 0.4874 - val_Fight_5_accuracy: 0.5630
# Epoch 7/10
# 475/475 [==============================] - 0s 321us/step - loss: 1.7115 - Fight_1_loss: 0.3309 - Fight_2_loss: 0.3657 - Fight_3_loss: 0.3195 - Fight_4_loss: 0.3192 - Fight_5_loss: 0.3762 - Fight_1_accuracy: 0.9011 - Fight_2_accuracy: 0.8674 - Fight_3_accuracy: 0.9158 - Fight_4_accuracy: 0.8968 - Fight_5_accuracy: 0.8716 - val_loss: 4.2757 - val_Fight_1_loss: 0.8480 - val_Fight_2_loss: 0.7262 - val_Fight_3_loss: 0.8736 - val_Fight_4_loss: 1.0002 - val_Fight_5_loss: 0.8458 - val_Fight_1_accuracy: 0.5042 - val_Fight_2_accuracy: 0.6050 - val_Fight_3_accuracy: 0.5630 - val_Fight_4_accuracy: 0.4454 - val_Fight_5_accuracy: 0.5462
# Epoch 8/10
# 475/475 [==============================] - 0s 327us/step - loss: 1.4930 - Fight_1_loss: 0.2840 - Fight_2_loss: 0.3001 - Fight_3_loss: 0.2748 - Fight_4_loss: 0.3151 - Fight_5_loss: 0.3213 - Fight_1_accuracy: 0.9221 - Fight_2_accuracy: 0.9242 - Fight_3_accuracy: 0.9116 - Fight_4_accuracy: 0.8884 - Fight_5_accuracy: 0.8926 - val_loss: 4.2274 - val_Fight_1_loss: 0.8542 - val_Fight_2_loss: 0.8313 - val_Fight_3_loss: 0.8609 - val_Fight_4_loss: 0.8647 - val_Fight_5_loss: 0.8299 - val_Fight_1_accuracy: 0.5546 - val_Fight_2_accuracy: 0.5714 - val_Fight_3_accuracy: 0.5630 - val_Fight_4_accuracy: 0.5378 - val_Fight_5_accuracy: 0.5798
# Epoch 9/10
# 475/475 [==============================] - 0s 393us/step - loss: 1.2748 - Fight_1_loss: 0.2477 - Fight_2_loss: 0.2590 - Fight_3_loss: 0.2324 - Fight_4_loss: 0.2536 - Fight_5_loss: 0.2832 - Fight_1_accuracy: 0.9263 - Fight_2_accuracy: 0.9389 - Fight_3_accuracy: 0.9495 - Fight_4_accuracy: 0.9221 - Fight_5_accuracy: 0.9179 - val_loss: 4.6674 - val_Fight_1_loss: 0.9808 - val_Fight_2_loss: 0.8334 - val_Fight_3_loss: 0.9547 - val_Fight_4_loss: 0.9137 - val_Fight_5_loss: 0.9965 - val_Fight_1_accuracy: 0.5714 - val_Fight_2_accuracy: 0.5714 - val_Fight_3_accuracy: 0.5882 - val_Fight_4_accuracy: 0.5378 - val_Fight_5_accuracy: 0.5294
# Epoch 10/10
# 475/475 [==============================] - 0s 311us/step - loss: 1.1108 - Fight_1_loss: 0.1990 - Fight_2_loss: 0.2400 - Fight_3_loss: 0.1782 - Fight_4_loss: 0.2206 - Fight_5_loss: 0.2753 - Fight_1_accuracy: 0.9579 - Fight_2_accuracy: 0.9326 - Fight_3_accuracy: 0.9768 - Fight_4_accuracy: 0.9411 - Fight_5_accuracy: 0.9053 - val_loss: 4.5640 - val_Fight_1_loss: 0.9928 - val_Fight_2_loss: 0.8727 - val_Fight_3_loss: 0.8803 - val_Fight_4_loss: 1.0353 - val_Fight_5_loss: 0.8150 - val_Fight_1_accuracy: 0.4958 - val_Fight_2_accuracy: 0.5798 - val_Fight_3_accuracy: 0.6050 - val_Fight_4_accuracy: 0.4706 - val_Fight_5_accuracy: 0.4958

# %%
plot_training()
