# %% [markdown]
# # In this Notebook we are attempting to predict a persons next N fights

# %% [markdown]
# ## Library Imports

# %%
import sys
sys.path.insert(1, '../combined_data')

import pandas as pd
import numpy as np
import talos as ta

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

from talos.model.normalizers import lr_normalizer
from talos.model.hidden_layers import hidden_layers

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Conv1D, Flatten, MaxPooling1D, LSTM, Input
from keras.optimizers import Adam, Nadam, RMSprop
from keras.losses import logcosh, binary_crossentropy
from keras.activations import relu, elu, sigmoid

import matplotlib.pyplot as plt
# %matplotlib inline

from make_career import make_career
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the dataset

# %%
features, labels = make_career(N_FIGHT_CAREER=10, N_FUTURE_LABELS=5)
# Out:
# Creating careers using 10 fight intervals and predicting 5 future fights
# Original fight data shape: (5062, 153)
# Fights 2x shape: (10124, 95)
#
# Features shape: (600, 10)
# Labels shape: (600, 5)
#
# Features is a 2D matrix with 600 rows
# Each row contains has 10 fights, and each fight has 100 keys
#
# Labels is a 2D matrix with 600 rows
# Each row contains the the prediction for the next 5 fight(s)

# %%
print('Features {}'.format(features.shape))
print('Labels {}'.format(labels.shape))
# Out:
# Features (600, 10)
# Labels (600, 5)

# %%
# Get the first fight window and the first fight in that window
def get_column_types():
    num_cols = []
    cat_cols = []
    for fight in features[0][0]:
        feature_type = type(features[1][1][fight])
        if feature_type is not float and feature_type is not int:
            cat_cols.append(fight)
        else:
            num_cols.append(fight)
            
    return num_cols, cat_cols


def plot_training_results(history_obj):
    acc = history_obj.history['accuracy']
    val_acc = history_obj.history['val_accuracy']
    loss = history_obj.history['loss']
    val_loss = history_obj.history['val_loss']
    
    epochs = range(1, len(acc) + 1)

    fig, (accuracy_axis, loss_axis) = plt.subplots(1, 2, figsize=(20, 5))

    accuracy_axis.plot(epochs, acc, 'bo', label='Training acc')
    accuracy_axis.plot(epochs, val_acc, 'b', label='Validation acc')
    accuracy_axis.set_title('Training and validation accuracy')
    accuracy_axis.set_ylabel('Accuracy')
    accuracy_axis.set_xlabel('Epoch')
    accuracy_axis.legend()

    loss_axis.plot(epochs, loss, 'bo', label='Training loss')
    loss_axis.plot(epochs, val_loss, 'b', label='Validation loss')
    loss_axis.set_title('Training and validation loss')
    loss_axis.set_ylim(0, 3)
    loss_axis.set_ylabel('Loss')
    loss_axis.set_xlabel('Epoch')
    loss_axis.legend()
    fig.show()

    
def plot_training_results():
    acc_1 = history.history['Fight_1_accuracy']
    acc_2 = history.history['Fight_2_accuracy']
    acc_3 = history.history['Fight_3_accuracy']
    acc_4 = history.history['Fight_4_accuracy']
    acc_5 = history.history['Fight_5_accuracy']
    
    val_acc_1 = history.history['val_Fight_1_accuracy']
    val_acc_2 = history.history['val_Fight_2_accuracy']
    val_acc_3 = history.history['val_Fight_3_accuracy']
    val_acc_4 = history.history['val_Fight_4_accuracy']
    val_acc_5 = history.history['val_Fight_5_accuracy']
    
    epochs = range(1, len(acc_1) + 1)

    fig, (accuracy_axis, training_axis) = plt.subplots(1, 2, figsize=(20, 5))

    accuracy_axis.plot(epochs, acc_1, 'b', label='Fight 1 Acc')
    accuracy_axis.plot(epochs, acc_2, 'g', label='Fight 2 Acc')
    accuracy_axis.plot(epochs, acc_3, 'r', label='Fight 3 Acc')
    accuracy_axis.plot(epochs, acc_4, 'c', label='Fight 4 Acc')
    accuracy_axis.plot(epochs, acc_5, 'm', label='Fight 5 Acc')
    accuracy_axis.set_title('Training Set Accuracy over time')
    accuracy_axis.set_ylabel('Accuracy')
    accuracy_axis.set_xlabel('Epoch')
    accuracy_axis.legend()
    
    training_axis.plot(epochs, val_acc_1, 'b', label='Fight 1 Acc')
    training_axis.plot(epochs, val_acc_2, 'g', label='Fight 2 Acc')
    training_axis.plot(epochs, val_acc_3, 'r', label='Fight 3 Acc')
    training_axis.plot(epochs, val_acc_4, 'c', label='Fight 4 Acc')
    training_axis.plot(epochs, val_acc_5, 'm', label='Fight 5 Acc')
    training_axis.set_title('Test Set Accuracy over time')
    training_axis.set_ylabel('Accuracy')
    training_axis.set_xlabel('Epoch')
    training_axis.legend()
    fig.show()

    
def encode_all_labels():
    encoded_labels = []
    for row in labels:
        new_labels_list = []
        for elem in row:
            if elem:
                new_labels_list.append(1)
            else:
                new_labels_list.append(0)
        encoded_labels.append(new_labels_list)
    encoded_labels = np.array(encoded_labels)
    
    return encoded_labels


def convert_labels(y_train):  
    fights_1 = np.array(y_train[:,0])
    fights_2 = np.array(y_train[:,1])
    fights_3 = np.array(y_train[:,2])
    fights_4 = np.array(y_train[:,3])
    fights_5 = np.array(y_train[:,4])
    
    y_train = [fights_1, fights_2, fights_3, fights_4, fights_5]
    return y_train

# %% [markdown]
# ## Preprocess Features

# %% [markdown]
# ## Generates np.array of shape (3220, 5 * features)

# %%
def collapse_n_fights():
    num_cols, cat_cols = get_column_types()
    
    # Collect only the features we want
    new_features = []
    for window in features:
        window_arr = list(window.reshape(1,-1))[0]
        fight_window = np.array([])
        for fight in window_arr:
            fight_arr = np.array([fight[i] for i in num_cols])
            np.nan_to_num(fight_arr, copy=False)
            fight_window = np.append(fight_window, fight_arr)
        new_features.append(fight_window)
    
    new_features, new_labels = shuffle(np.array(new_features), labels)
    X_train, X_test, y_train, y_test = train_test_split(new_features, new_labels, random_state=0, train_size=0.99)
    
    # Scale the data
    scaler = StandardScaler().fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    print('X_train length {}, y_train length {}'.format(X_train.shape, y_train.shape))
    print('X_test length {}, y_test length {}'.format(X_test.shape, y_test.shape))

    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Building a CNN to predict the winner using last n fights

# %%
# Get the data
labels = encode_all_labels()
X_train, X_test, y_train, y_test = collapse_n_fights()
X_train = X_train.reshape(X_train.shape[0], 10, 97)
X_test = X_test.reshape(X_test.shape[0], 10, 97)

y_train = np.array(convert_labels(y_train))
y_test = np.array(convert_labels(y_test))
# Out:
# X_train length (594, 970), y_train length (594, 5)
# X_test length (6, 970), y_test length (6, 5)

# %%
def get_ensemble():
    # x_train, y_train, x_val, y_val, params, test_model=False
    fight_input = Input(shape=(10, 97), name="Input")
    x = Conv1D(filters=128, kernel_size=2, activation='relu', name="Conv_1D")(fight_input)
    x = Dropout(0.01, name="Dropout")(x)
    x = Flatten(name="Flatten")(x)

    # Global Dense Network
    x = Dense(128, activation='relu', name="Global_Dense")(x)

    # 5 output layers
    fight_1 = Dense(1, activation='sigmoid', name="Fight_1")(x)
    fight_2 = Dense(1, activation='sigmoid', name="Fight_2")(x)
    fight_3 = Dense(1, activation='sigmoid', name="Fight_3")(x)
    fight_4 = Dense(1, activation='sigmoid', name="Fight_4")(x)
    fight_5 = Dense(1, activation='sigmoid', name="Fight_5")(x)

    model = Model(inputs=fight_input,
                  outputs=[fight_1, fight_2, fight_3, fight_4, fight_5])
    
    model.compile(optimizer='rmsprop',
                 loss={"Fight_1": "binary_crossentropy", 
                       "Fight_2": "binary_crossentropy",
                       "Fight_3": "binary_crossentropy",
                       "Fight_4": "binary_crossentropy",
                       "Fight_5": "binary_crossentropy"},
                 loss_weights={"Fight_1": 1., 
                               "Fight_2": 1.,
                               "Fight_3": 1.,
                               "Fight_4": 1.,
                               "Fight_5": 1.},
                 metrics={"Fight_1": "accuracy", 
                          "Fight_2": "accuracy",
                          "Fight_3": "accuracy",
                          "Fight_4": "accuracy",
                          "Fight_5": "accuracy"})

    model.summary()
    return model

model = get_ensemble()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 10, 97)       0
# __________________________________________________________________________________________________
# Conv_1D (Conv1D)                (None, 9, 128)       24960       Input[0][0]
# __________________________________________________________________________________________________
# Dropout (Dropout)               (None, 9, 128)       0           Conv_1D[0][0]
# __________________________________________________________________________________________________
# Flatten (Flatten)               (None, 1152)         0           Dropout[0][0]
# __________________________________________________________________________________________________
# Global_Dense (Dense)            (None, 128)          147584      Flatten[0][0]
# __________________________________________________________________________________________________
# Fight_1 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_2 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_3 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_4 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# __________________________________________________________________________________________________
# Fight_5 (Dense)                 (None, 1)            129         Global_Dense[0][0]
# ==================================================================================================
# Total params: 173,189
# Trainable params: 173,189
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train,
                    {'Fight_1': y_train[0], 
                     'Fight_2': y_train[1], 
                     'Fight_3': y_train[2], 
                     'Fight_4': y_train[3],
                     'Fight_5': y_train[4],},
                   validation_split=0.2,
                   batch_size=32,
                   epochs=10,
                   verbose=1)
# Out:
# Train on 475 samples, validate on 119 samples
# Epoch 1/10
# 475/475 [==============================] - 1s 2ms/step - loss: 3.8981 - Fight_1_loss: 0.7242 - Fight_2_loss: 0.8032 - Fight_3_loss: 0.7605 - Fight_4_loss: 0.7793 - Fight_5_loss: 0.8249 - Fight_1_accuracy: 0.5958 - Fight_2_accuracy: 0.5684 - Fight_3_accuracy: 0.5200 - Fight_4_accuracy: 0.4716 - Fight_5_accuracy: 0.5074 - val_loss: 3.6110 - val_Fight_1_loss: 0.6797 - val_Fight_2_loss: 0.7253 - val_Fight_3_loss: 0.7076 - val_Fight_4_loss: 0.7626 - val_Fight_5_loss: 0.7431 - val_Fight_1_accuracy: 0.5798 - val_Fight_2_accuracy: 0.5966 - val_Fight_3_accuracy: 0.5210 - val_Fight_4_accuracy: 0.5378 - val_Fight_5_accuracy: 0.5294
# Epoch 2/10
# 475/475 [==============================] - 0s 348us/step - loss: 3.0649 - Fight_1_loss: 0.6046 - Fight_2_loss: 0.5895 - Fight_3_loss: 0.6149 - Fight_4_loss: 0.6318 - Fight_5_loss: 0.6243 - Fight_1_accuracy: 0.7137 - Fight_2_accuracy: 0.6568 - Fight_3_accuracy: 0.6632 - Fight_4_accuracy: 0.6463 - Fight_5_accuracy: 0.6632 - val_loss: 3.7337 - val_Fight_1_loss: 0.6804 - val_Fight_2_loss: 0.7147 - val_Fight_3_loss: 0.8167 - val_Fight_4_loss: 0.7355 - val_Fight_5_loss: 0.7898 - val_Fight_1_accuracy: 0.6723 - val_Fight_2_accuracy: 0.5966 - val_Fight_3_accuracy: 0.5378 - val_Fight_4_accuracy: 0.5126 - val_Fight_5_accuracy: 0.5546
# Epoch 3/10
# 475/475 [==============================] - 0s 226us/step - loss: 2.7858 - Fight_1_loss: 0.5532 - Fight_2_loss: 0.5359 - Fight_3_loss: 0.5594 - Fight_4_loss: 0.5719 - Fight_5_loss: 0.5675 - Fight_1_accuracy: 0.7600 - Fight_2_accuracy: 0.7326 - Fight_3_accuracy: 0.7158 - Fight_4_accuracy: 0.7095 - Fight_5_accuracy: 0.7074 - val_loss: 3.6903 - val_Fight_1_loss: 0.6737 - val_Fight_2_loss: 0.7436 - val_Fight_3_loss: 0.7378 - val_Fight_4_loss: 0.7429 - val_Fight_5_loss: 0.8125 - val_Fight_1_accuracy: 0.6975 - val_Fight_2_accuracy: 0.5210 - val_Fight_3_accuracy: 0.5462 - val_Fight_4_accuracy: 0.5294 - val_Fight_5_accuracy: 0.4538
# Epoch 4/10
# 475/475 [==============================] - 0s 465us/step - loss: 2.4775 - Fight_1_loss: 0.4882 - Fight_2_loss: 0.4797 - Fight_3_loss: 0.4950 - Fight_4_loss: 0.5013 - Fight_5_loss: 0.5144 - Fight_1_accuracy: 0.7874 - Fight_2_accuracy: 0.7853 - Fight_3_accuracy: 0.7747 - Fight_4_accuracy: 0.7811 - Fight_5_accuracy: 0.7705 - val_loss: 3.7309 - val_Fight_1_loss: 0.7175 - val_Fight_2_loss: 0.7428 - val_Fight_3_loss: 0.7755 - val_Fight_4_loss: 0.6866 - val_Fight_5_loss: 0.8269 - val_Fight_1_accuracy: 0.6555 - val_Fight_2_accuracy: 0.5378 - val_Fight_3_accuracy: 0.5882 - val_Fight_4_accuracy: 0.5798 - val_Fight_5_accuracy: 0.4874
# Epoch 5/10
# 475/475 [==============================] - 0s 210us/step - loss: 2.2362 - Fight_1_loss: 0.4439 - Fight_2_loss: 0.4435 - Fight_3_loss: 0.4385 - Fight_4_loss: 0.4562 - Fight_5_loss: 0.4551 - Fight_1_accuracy: 0.8168 - Fight_2_accuracy: 0.8168 - Fight_3_accuracy: 0.8211 - Fight_4_accuracy: 0.8063 - Fight_5_accuracy: 0.8400 - val_loss: 3.8671 - val_Fight_1_loss: 0.7574 - val_Fight_2_loss: 0.7638 - val_Fight_3_loss: 0.7714 - val_Fight_4_loss: 0.7521 - val_Fight_5_loss: 0.8345 - val_Fight_1_accuracy: 0.6050 - val_Fight_2_accuracy: 0.5126 - val_Fight_3_accuracy: 0.5546 - val_Fight_4_accuracy: 0.5630 - val_Fight_5_accuracy: 0.4958
# Epoch 6/10
# 475/475 [==============================] - 0s 194us/step - loss: 1.9537 - Fight_1_loss: 0.3991 - Fight_2_loss: 0.3687 - Fight_3_loss: 0.3818 - Fight_4_loss: 0.3945 - Fight_5_loss: 0.4122 - Fight_1_accuracy: 0.8611 - Fight_2_accuracy: 0.8737 - Fight_3_accuracy: 0.8505 - Fight_4_accuracy: 0.8737 - Fight_5_accuracy: 0.8379 - val_loss: 4.1937 - val_Fight_1_loss: 0.7988 - val_Fight_2_loss: 0.8243 - val_Fight_3_loss: 0.7816 - val_Fight_4_loss: 0.8919 - val_Fight_5_loss: 0.9368 - val_Fight_1_accuracy: 0.5210 - val_Fight_2_accuracy: 0.5126 - val_Fight_3_accuracy: 0.6218 - val_Fight_4_accuracy: 0.5798 - val_Fight_5_accuracy: 0.4874
# Epoch 7/10
# 475/475 [==============================] - 0s 168us/step - loss: 1.7085 - Fight_1_loss: 0.3504 - Fight_2_loss: 0.2962 - Fight_3_loss: 0.3416 - Fight_4_loss: 0.3631 - Fight_5_loss: 0.3575 - Fight_1_accuracy: 0.8758 - Fight_2_accuracy: 0.9074 - Fight_3_accuracy: 0.8842 - Fight_4_accuracy: 0.8611 - Fight_5_accuracy: 0.8800 - val_loss: 4.2280 - val_Fight_1_loss: 0.9050 - val_Fight_2_loss: 0.8085 - val_Fight_3_loss: 0.7760 - val_Fight_4_loss: 0.7926 - val_Fight_5_loss: 0.9685 - val_Fight_1_accuracy: 0.4538 - val_Fight_2_accuracy: 0.5126 - val_Fight_3_accuracy: 0.5630 - val_Fight_4_accuracy: 0.5714 - val_Fight_5_accuracy: 0.5126
# Epoch 8/10
# 475/475 [==============================] - 0s 170us/step - loss: 1.4768 - Fight_1_loss: 0.3192 - Fight_2_loss: 0.2615 - Fight_3_loss: 0.2741 - Fight_4_loss: 0.2837 - Fight_5_loss: 0.3372 - Fight_1_accuracy: 0.8926 - Fight_2_accuracy: 0.9263 - Fight_3_accuracy: 0.9305 - Fight_4_accuracy: 0.9411 - Fight_5_accuracy: 0.8842 - val_loss: 4.2078 - val_Fight_1_loss: 0.8345 - val_Fight_2_loss: 0.8718 - val_Fight_3_loss: 0.8309 - val_Fight_4_loss: 0.7891 - val_Fight_5_loss: 0.9005 - val_Fight_1_accuracy: 0.5042 - val_Fight_2_accuracy: 0.5126 - val_Fight_3_accuracy: 0.5546 - val_Fight_4_accuracy: 0.5546 - val_Fight_5_accuracy: 0.5630
# Epoch 9/10
# 475/475 [==============================] - 0s 186us/step - loss: 1.2734 - Fight_1_loss: 0.3220 - Fight_2_loss: 0.2332 - Fight_3_loss: 0.2379 - Fight_4_loss: 0.2315 - Fight_5_loss: 0.2504 - Fight_1_accuracy: 0.8968 - Fight_2_accuracy: 0.9389 - Fight_3_accuracy: 0.9453 - Fight_4_accuracy: 0.9579 - Fight_5_accuracy: 0.9263 - val_loss: 4.3982 - val_Fight_1_loss: 0.7976 - val_Fight_2_loss: 0.9793 - val_Fight_3_loss: 0.8752 - val_Fight_4_loss: 0.8715 - val_Fight_5_loss: 0.9014 - val_Fight_1_accuracy: 0.5966 - val_Fight_2_accuracy: 0.5714 - val_Fight_3_accuracy: 0.6050 - val_Fight_4_accuracy: 0.5378 - val_Fight_5_accuracy: 0.5378
# Epoch 10/10
# 475/475 [==============================] - 0s 187us/step - loss: 1.0061 - Fight_1_loss: 0.2181 - Fight_2_loss: 0.1741 - Fight_3_loss: 0.1898 - Fight_4_loss: 0.2106 - Fight_5_loss: 0.2149 - Fight_1_accuracy: 0.9537 - Fight_2_accuracy: 0.9726 - Fight_3_accuracy: 0.9684 - Fight_4_accuracy: 0.9642 - Fight_5_accuracy: 0.9621 - val_loss: 4.9568 - val_Fight_1_loss: 1.1867 - val_Fight_2_loss: 0.8988 - val_Fight_3_loss: 1.0169 - val_Fight_4_loss: 0.8441 - val_Fight_5_loss: 1.0304 - val_Fight_1_accuracy: 0.4370 - val_Fight_2_accuracy: 0.5294 - val_Fight_3_accuracy: 0.5210 - val_Fight_4_accuracy: 0.5630 - val_Fight_5_accuracy: 0.5462

# %%
plot_training_results()

# %%
acc = [0.58, 0.60, 0.58]
f1 = [0.69, 0.68, 0.63]
index = ['DNN', '1D CNN', "LSTM"]
df = pd.DataFrame({'Accuracy': acc,
                   'F Score': f1}, index=index)
ax = df.plot.bar(rot=0, figsize=(15,8))
ax.set_ylim(0,1)
ax.set_title("Comparison of several models")
ax.set_ylabel("Accuracy")
ax.set_xlabel("Model Type")
# Out:
# Text(0.5, 0, 'Model Type')
