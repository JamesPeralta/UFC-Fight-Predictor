# %%
import pandas as pd
from unidecode import unidecode

# reading the kaggle dataset
kaggle_data = pd.read_csv('../ufcdata/data.csv')

# reading the elevations dataset(scraped)
elevations_data = pd.read_csv('../elevations/locations_elevation_updated.csv')

# %%
# fixing one location entry in the kaggle dataset
kaggle_data.loc[kaggle_data['location'] == 'Singapore, Singapore'] = 'Marina Bay, Singapore'

def cleanLocationsForJoin(strs):
    words = strs.split(',')
    return (', '.join([unidecode(words[0].strip()), unidecode(words[-1].strip())]))

# preparing data for joining
kaggle_data['merge_location'] = kaggle_data['location'].apply(cleanLocationsForJoin)
elevations_data['merge_location'] = elevations_data['location'].apply(cleanLocationsForJoin)

#dropping the original location column from elevations dataset by keeping in kaggle dataset to use later
elevations_data.drop(columns=['location'], inplace=True)

# removing meter(m) abbr. from the elevation column and changing data type to float
elevations_data['location_elevation'] = elevations_data['location_elevation'].apply(lambda x: float(x.split()[0]))

# %%
# printing the basic statistics of both datasets
def printColumnStats(dataset):
    for column in dataset.columns:
        print('{:30s}'.format(column), dataset[column].dtype)

# shape of kaggle dataset
print('Kaggle dataset shape:', '{}\n'.format(kaggle_data.shape))
printColumnStats(kaggle_data)
print('\n\n')

# shape of elevations dataset
print('Elevations dataset shape:', '{}\n'.format(elevations_data.shape))
printColumnStats(elevations_data)
# Out:
# Kaggle dataset shape: (5144, 146)
#
# R_fighter                      object
# B_fighter                      object
# Referee                        object
# date                           object
# location                       object
# Winner                         object
# title_bout                     object
# weight_class                   object
# no_of_rounds                   object
# B_current_lose_streak          object
# B_current_win_streak           object
# B_draw                         object
# B_avg_BODY_att                 object
# B_avg_BODY_landed              object
# B_avg_CLINCH_att               object
# B_avg_CLINCH_landed            object
# B_avg_DISTANCE_att             object
# B_avg_DISTANCE_landed          object
# B_avg_GROUND_att               object
# B_avg_GROUND_landed            object
# B_avg_HEAD_att                 object
# B_avg_HEAD_landed              object
# B_avg_KD                       object
# B_avg_LEG_att                  object
# B_avg_LEG_landed               object
# B_avg_PASS                     object
# B_avg_REV                      object
# B_avg_SIG_STR_att              object
# B_avg_SIG_STR_landed           object
# B_avg_SIG_STR_pct              object
# B_avg_SUB_ATT                  object
# B_avg_TD_att                   object
# B_avg_TD_landed                object
# B_avg_TD_pct                   object
# B_avg_TOTAL_STR_att            object
# B_avg_TOTAL_STR_landed         object
# B_longest_win_streak           object
# B_losses                       object
# B_avg_opp_BODY_att             object
# B_avg_opp_BODY_landed          object
# B_avg_opp_CLINCH_att           object
# B_avg_opp_CLINCH_landed        object
# B_avg_opp_DISTANCE_att         object
# B_avg_opp_DISTANCE_landed      object
# B_avg_opp_GROUND_att           object
# B_avg_opp_GROUND_landed        object
# B_avg_opp_HEAD_att             object
# B_avg_opp_HEAD_landed          object
# B_avg_opp_KD                   object
# B_avg_opp_LEG_att              object
# B_avg_opp_LEG_landed           object
# B_avg_opp_PASS                 object
# B_avg_opp_REV                  object
# B_avg_opp_SIG_STR_att          object
# B_avg_opp_SIG_STR_landed       object
# B_avg_opp_SIG_STR_pct          object
# B_avg_opp_SUB_ATT              object
# B_avg_opp_TD_att               object
# B_avg_opp_TD_landed            object
# B_avg_opp_TD_pct               object
# B_avg_opp_TOTAL_STR_att        object
# B_avg_opp_TOTAL_STR_landed     object
# B_total_rounds_fought          object
# B_total_time_fought(seconds)   object
# B_total_title_bouts            object
# B_win_by_Decision_Majority     object
# B_win_by_Decision_Split        object
# B_win_by_Decision_Unanimous    object
# B_win_by_KO/TKO                object
# B_win_by_Submission            object
# B_win_by_TKO_Doctor_Stoppage   object
# B_wins                         object
# B_Stance                       object
# B_Height_cms                   object
# B_Reach_cms                    object
# B_Weight_lbs                   object
# R_current_lose_streak          object
# R_current_win_streak           object
# R_draw                         object
# R_avg_BODY_att                 object
# R_avg_BODY_landed              object
# R_avg_CLINCH_att               object
# R_avg_CLINCH_landed            object
# R_avg_DISTANCE_att             object
# R_avg_DISTANCE_landed          object
# R_avg_GROUND_att               object
# R_avg_GROUND_landed            object
# R_avg_HEAD_att                 object
# R_avg_HEAD_landed              object
# R_avg_KD                       object
# R_avg_LEG_att                  object
# R_avg_LEG_landed               object
# R_avg_PASS                     object
# R_avg_REV                      object
# R_avg_SIG_STR_att              object
# R_avg_SIG_STR_landed           object
# R_avg_SIG_STR_pct              object
# R_avg_SUB_ATT                  object
# R_avg_TD_att                   object
# R_avg_TD_landed                object
# R_avg_TD_pct                   object
# R_avg_TOTAL_STR_att            object
# R_avg_TOTAL_STR_landed         object
# R_longest_win_streak           object
# R_losses                       object
# R_avg_opp_BODY_att             object
# R_avg_opp_BODY_landed          object
# R_avg_opp_CLINCH_att           object
# R_avg_opp_CLINCH_landed        object
# R_avg_opp_DISTANCE_att         object
# R_avg_opp_DISTANCE_landed      object
# R_avg_opp_GROUND_att           object
# R_avg_opp_GROUND_landed        object
# R_avg_opp_HEAD_att             object
# R_avg_opp_HEAD_landed          object
# R_avg_opp_KD                   object
# R_avg_opp_LEG_att              object
# R_avg_opp_LEG_landed           object
# R_avg_opp_PASS                 object
# R_avg_opp_REV                  object
# R_avg_opp_SIG_STR_att          object
# R_avg_opp_SIG_STR_landed       object
# R_avg_opp_SIG_STR_pct          object
# R_avg_opp_SUB_ATT              object
# R_avg_opp_TD_att               object
# R_avg_opp_TD_landed            object
# R_avg_opp_TD_pct               object
# R_avg_opp_TOTAL_STR_att        object
# R_avg_opp_TOTAL_STR_landed     object
# R_total_rounds_fought          object
# R_total_time_fought(seconds)   object
# R_total_title_bouts            object
# R_win_by_Decision_Majority     object
# R_win_by_Decision_Split        object
# R_win_by_Decision_Unanimous    object
# R_win_by_KO/TKO                object
# R_win_by_Submission            object
# R_win_by_TKO_Doctor_Stoppage   object
# R_wins                         object
# R_Stance                       object
# R_Height_cms                   object
# R_Reach_cms                    object
# R_Weight_lbs                   object
# B_age                          object
# R_age                          object
# merge_location                 object
#
#
#
# Elevations dataset shape: (163, 2)
#
# location_elevation             float64
# merge_location                 object

# %%
# join the two columns to add the elevations for locations
joined_data = kaggle_data.set_index('merge_location').join(elevations_data.set_index('merge_location')).reset_index()

#dropping the merge location column from joined dataset, the location is under location column
joined_data.drop(columns=['merge_location'], inplace=True)

# printing the stats of the newly joined dataset
print('Joined dataset shape:', '{}\n'.format(joined_data.shape))
printColumnStats(joined_data)
# Out:
# Joined dataset shape: (5144, 146)
#
# R_fighter                      object
# B_fighter                      object
# Referee                        object
# date                           object
# location                       object
# Winner                         object
# title_bout                     object
# weight_class                   object
# no_of_rounds                   object
# B_current_lose_streak          object
# B_current_win_streak           object
# B_draw                         object
# B_avg_BODY_att                 object
# B_avg_BODY_landed              object
# B_avg_CLINCH_att               object
# B_avg_CLINCH_landed            object
# B_avg_DISTANCE_att             object
# B_avg_DISTANCE_landed          object
# B_avg_GROUND_att               object
# B_avg_GROUND_landed            object
# B_avg_HEAD_att                 object
# B_avg_HEAD_landed              object
# B_avg_KD                       object
# B_avg_LEG_att                  object
# B_avg_LEG_landed               object
# B_avg_PASS                     object
# B_avg_REV                      object
# B_avg_SIG_STR_att              object
# B_avg_SIG_STR_landed           object
# B_avg_SIG_STR_pct              object
# B_avg_SUB_ATT                  object
# B_avg_TD_att                   object
# B_avg_TD_landed                object
# B_avg_TD_pct                   object
# B_avg_TOTAL_STR_att            object
# B_avg_TOTAL_STR_landed         object
# B_longest_win_streak           object
# B_losses                       object
# B_avg_opp_BODY_att             object
# B_avg_opp_BODY_landed          object
# B_avg_opp_CLINCH_att           object
# B_avg_opp_CLINCH_landed        object
# B_avg_opp_DISTANCE_att         object
# B_avg_opp_DISTANCE_landed      object
# B_avg_opp_GROUND_att           object
# B_avg_opp_GROUND_landed        object
# B_avg_opp_HEAD_att             object
# B_avg_opp_HEAD_landed          object
# B_avg_opp_KD                   object
# B_avg_opp_LEG_att              object
# B_avg_opp_LEG_landed           object
# B_avg_opp_PASS                 object
# B_avg_opp_REV                  object
# B_avg_opp_SIG_STR_att          object
# B_avg_opp_SIG_STR_landed       object
# B_avg_opp_SIG_STR_pct          object
# B_avg_opp_SUB_ATT              object
# B_avg_opp_TD_att               object
# B_avg_opp_TD_landed            object
# B_avg_opp_TD_pct               object
# B_avg_opp_TOTAL_STR_att        object
# B_avg_opp_TOTAL_STR_landed     object
# B_total_rounds_fought          object
# B_total_time_fought(seconds)   object
# B_total_title_bouts            object
# B_win_by_Decision_Majority     object
# B_win_by_Decision_Split        object
# B_win_by_Decision_Unanimous    object
# B_win_by_KO/TKO                object
# B_win_by_Submission            object
# B_win_by_TKO_Doctor_Stoppage   object
# B_wins                         object
# B_Stance                       object
# B_Height_cms                   object
# B_Reach_cms                    object
# B_Weight_lbs                   object
# R_current_lose_streak          object
# R_current_win_streak           object
# R_draw                         object
# R_avg_BODY_att                 object
# R_avg_BODY_landed              object
# R_avg_CLINCH_att               object
# R_avg_CLINCH_landed            object
# R_avg_DISTANCE_att             object
# R_avg_DISTANCE_landed          object
# R_avg_GROUND_att               object
# R_avg_GROUND_landed            object
# R_avg_HEAD_att                 object
# R_avg_HEAD_landed              object
# R_avg_KD                       object
# R_avg_LEG_att                  object
# R_avg_LEG_landed               object
# R_avg_PASS                     object
# R_avg_REV                      object
# R_avg_SIG_STR_att              object
# R_avg_SIG_STR_landed           object
# R_avg_SIG_STR_pct              object
# R_avg_SUB_ATT                  object
# R_avg_TD_att                   object
# R_avg_TD_landed                object
# R_avg_TD_pct                   object
# R_avg_TOTAL_STR_att            object
# R_avg_TOTAL_STR_landed         object
# R_longest_win_streak           object
# R_losses                       object
# R_avg_opp_BODY_att             object
# R_avg_opp_BODY_landed          object
# R_avg_opp_CLINCH_att           object
# R_avg_opp_CLINCH_landed        object
# R_avg_opp_DISTANCE_att         object
# R_avg_opp_DISTANCE_landed      object
# R_avg_opp_GROUND_att           object
# R_avg_opp_GROUND_landed        object
# R_avg_opp_HEAD_att             object
# R_avg_opp_HEAD_landed          object
# R_avg_opp_KD                   object
# R_avg_opp_LEG_att              object
# R_avg_opp_LEG_landed           object
# R_avg_opp_PASS                 object
# R_avg_opp_REV                  object
# R_avg_opp_SIG_STR_att          object
# R_avg_opp_SIG_STR_landed       object
# R_avg_opp_SIG_STR_pct          object
# R_avg_opp_SUB_ATT              object
# R_avg_opp_TD_att               object
# R_avg_opp_TD_landed            object
# R_avg_opp_TD_pct               object
# R_avg_opp_TOTAL_STR_att        object
# R_avg_opp_TOTAL_STR_landed     object
# R_total_rounds_fought          object
# R_total_time_fought(seconds)   object
# R_total_title_bouts            object
# R_win_by_Decision_Majority     object
# R_win_by_Decision_Split        object
# R_win_by_Decision_Unanimous    object
# R_win_by_KO/TKO                object
# R_win_by_Submission            object
# R_win_by_TKO_Doctor_Stoppage   object
# R_wins                         object
# R_Stance                       object
# R_Height_cms                   object
# R_Reach_cms                    object
# R_Weight_lbs                   object
# B_age                          object
# R_age                          object
# location_elevation             float64

# %%
# checking the integrity of the joined location elevations data
print('Empty Location Values:', joined_data['location_elevation'].isnull().any())
# Out:
# Empty Location Values: False

# %%
# creating a new csv
joined_data.to_csv('../ufcdata/data_with_location_elevation.csv')
